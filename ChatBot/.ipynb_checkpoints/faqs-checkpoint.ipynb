# %% [markdown]
# # Import modules

# %%
import os
import pandas as pd
import chromadb
from chromadb.utils import embedding_functions
from dotenv import load_dotenv
from groq import Groq

# %% [markdown]
# # Load environment variables

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Create Vector Database

# %%
client = chromadb.Client()

# %% [markdown]
# # Load content to Vector DB

# %%
embedder = embedding_functions.SentenceTransformerEmbeddingFunction(
            model_name="all-MiniLM-L6-v2"
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# WARNING:tensorflow:From D:\EDUeki Learning\AMPT\Learning\pr\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
collection = client.get_or_create_collection(
            name="qa_chat",
            embedding_function=embedder,
            metadata={"hnsw:space": "cosine"},
        )

# %%
data = pd.read_csv("data.csv")
questions = data["question"].astype(str).tolist()
questions[:2]
# Out:
# ['What courses do you offer?', 'How do I enroll in a course?']

# %%
answers = [{"answer": a} for a in data["answer"].astype(str).tolist()]
answers[:3]
# Out:
# [{'answer': 'We offer self‑paced professional courses in DevOps, cloud, infrastructure as code, CI/CD, monitoring, and related real‑world tech topics.'},
#  {'answer': 'To enroll, create an account, browse the available courses, and click ‘Enroll’ or ‘Start Learning’.'},
#  {'answer': 'We occasionally provide trial lessons or previews—please check the individual course page or contact support for current offers.'}]

# %%
ids = [f"id_{i}" for i in range(len(questions))]
ids[:3]
# Out:
# ['id_0', 'id_1', 'id_2']

# %%
collection.upsert(documents=questions, metadatas=answers, ids=ids)

# %% [markdown]
# # Create Query

# %%
query = "how much is the AIML course fee?"

# %%
def _normalize_query(q: str) -> str:
        return q.strip().rstrip(" ?!.")
query = _normalize_query(query)

# %%
query
# Out:
# 'how much is the AIML course fee'

# %%
q_emb = embedder([query])[0]

# %% [markdown]
# # Query the Vector Database

# %%
results = collection.query(query_embeddings=[q_emb], n_results=5)

# %%
results
# Out:
# {'ids': [['id_21', 'id_1', 'id_15', 'id_5', 'id_0']],
#  'embeddings': None,
#  'documents': [['What will be the AIML course fee?',
#    'How do I enroll in a course?',
#    'Can I upgrade my plan or switch to another course?',
#    'What is included in the course materials?',
#    'What courses do you offer?']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'answer': ' Regular fee is 30 INR Please check with Admin team for personal discount coupouns.'},
#    {'answer': 'To enroll, create an account, browse the available courses, and click ‘Enroll’ or ‘Start Learning’.'},
#    {'answer': 'Yes, you can upgrade or switch to another course by contacting our support team for guidance on the best path forward.'},
#    {'answer': 'Each course includes video lectures, transcripts, reading materials, quizzes, and assessments.'},
#    {'answer': 'We offer self‑paced professional courses in DevOps, cloud, infrastructure as code, CI/CD, monitoring, and related real‑world tech topics.'}]],
#  'distances': [[0.09538733959197998,
#    0.5828702449798584,
#    0.5938010215759277,
#    0.6262227296829224,
#    0.6363245844841003]]}

# %%
documents = results['documents'][0]

# %%
documents
# Out:
# ['What will be the AIML course fee?',
#  'How do I enroll in a course?',
#  'Can I upgrade my plan or switch to another course?',
#  'What is included in the course materials?',
#  'What courses do you offer?']

# %%
metadatas = results['metadatas'][0]

# %%
metadatas
# Out:
# [{'answer': ' Regular fee is 30 INR Please check with Admin team for personal discount coupouns.'},
#  {'answer': 'To enroll, create an account, browse the available courses, and click ‘Enroll’ or ‘Start Learning’.'},
#  {'answer': 'Yes, you can upgrade or switch to another course by contacting our support team for guidance on the best path forward.'},
#  {'answer': 'Each course includes video lectures, transcripts, reading materials, quizzes, and assessments.'},
#  {'answer': 'We offer self‑paced professional courses in DevOps, cloud, infrastructure as code, CI/CD, monitoring, and related real‑world tech topics.'}]

# %%
pairs = []
for d, m in zip(documents, metadatas):
    a = (m.get("answer", "") if isinstance(m, dict) else "")
    if d or a:
        pairs.append(f"Q: {d}\nA: {a}")

context = "\n\n".join(pairs).strip()
context
# Out:
# 'Q: What will be the AIML course fee?\nA:  Regular fee is 30 INR Please check with Admin team for personal discount coupouns.\n\nQ: How do I enroll in a course?\nA: To enroll, create an account, browse the available courses, and click ‘Enroll’ or ‘Start Learning’.\n\nQ: Can I upgrade my plan or switch to another course?\nA: Yes, you can upgrade or switch to another course by contacting our support team for guidance on the best path forward.\n\nQ: What is included in the course materials?\nA: Each course includes video lectures, transcripts, reading materials, quizzes, and assessments.\n\nQ: What courses do you offer?\nA: We offer self‑paced professional courses in DevOps, cloud, infrastructure as code, CI/CD, monitoring, and related real‑world tech topics.'

# %% [markdown]
# # Create Prompt

# %%
prompt = f"""
    You are a helpful FAQ assistant. Use ONLY the context to answer.
    Rewrite the answer in clear, friendly language (not verbatim), and format it nicely.
    - If the question asks for "course content", "course index", or similar: present a clean, ordered outline.
    - If context includes lists, use bullets or numbered steps.
    - If dates, prices, or times appear, surface them clearly (you may bold them).
    - If multiple Q/A pairs are relevant, synthesize them into one concise answer.
    - At the end of the answer, mention the following line only if the user’s query is about pricing: Are you interested in joining the AIML course to become an AI Expert? I can check if there are any special discounts available for you!
    If the answer is not in the context, reply exactly: "I don't know".

    Question: {query}

    Context:
    {context}
    """

# %%
prompt
# Out:
# '\n    You are a helpful FAQ assistant. Use ONLY the context to answer.\n    Rewrite the answer in clear, friendly language (not verbatim), and format it nicely.\n    - If the question asks for "course content", "course index", or similar: present a clean, ordered outline.\n    - If context includes lists, use bullets or numbered steps.\n    - If dates, prices, or times appear, surface them clearly (you may bold them).\n    - If multiple Q/A pairs are relevant, synthesize them into one concise answer.\n    - At the end of the answer, mention the following line only if the user’s query is about pricing: Are you interested in joining the AIML course to become an AI Expert? I can check if there are any special discounts available for you!\n    If the answer is not in the context, reply exactly: "I don\'t know".\n\n    Question: how much is the AIML course fee\n\n    Context:\n    Q: What will be the AIML course fee?\nA:  Regular fee is 30 INR Please check with Admin team for personal discount coupouns.\n\nQ: How do I enroll in a course?\nA: To enroll, create an account, browse the available courses, and click ‘Enroll’ or ‘Start Learning’.\n\nQ: Can I upgrade my plan or switch to another course?\nA: Yes, you can upgrade or switch to another course by contacting our support team for guidance on the best path forward.\n\nQ: What is included in the course materials?\nA: Each course includes video lectures, transcripts, reading materials, quizzes, and assessments.\n\nQ: What courses do you offer?\nA: We offer self‑paced professional courses in DevOps, cloud, infrastructure as code, CI/CD, monitoring, and related real‑world tech topics.\n    '

# %% [markdown]
# # Query the LLM

# %%
groq = Groq()
llm_answer = groq.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[{"role": "user", "content": prompt}],
        )

# %%
llm_answer
# Out:
# ChatCompletion(id='chatcmpl-3828da10-755b-48e6-a9fb-1581fde14a53', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='**The regular fee for the AIML course is 30 INR**. However, you may be eligible for a personal discount. To find out, please **check with the Admin team for personal discount coupons**.\nAre you interested in joining the AIML course to become an AI Expert? I can check if there are any special discounts available for you!', role='assistant', executed_tools=None, function_call=None, reasoning=None, tool_calls=None))], created=1760386850, model='llama-3.3-70b-versatile', object='chat.completion', system_fingerprint='fp_155ab82e98', usage=CompletionUsage(completion_tokens=73, prompt_tokens=406, total_tokens=479, completion_time=0.179275916, prompt_time=0.035280737, queue_time=0.199867432, total_time=0.214556653), usage_breakdown=None, x_groq={'id': 'req_01k7fkq7bvfaqv7bcgnb1hjctp'}, service_tier='on_demand')

# %%
llm_answer.choices[0]
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='**The regular fee for the AIML course is 30 INR**. However, you may be eligible for a personal discount. To find out, please **check with the Admin team for personal discount coupons**.\nAre you interested in joining the AIML course to become an AI Expert? I can check if there are any special discounts available for you!', role='assistant', executed_tools=None, function_call=None, reasoning=None, tool_calls=None))

# %%
answer = llm_answer.choices[0].message.content

# %% [markdown]
# # RAG Pipeline completed
