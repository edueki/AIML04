# %%
# !python3 -m pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#   Using cached numpy-2.4.6-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
# Using cached pandas-3.0.3-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
# Using cached numpy-2.4.6-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        3                  3       Graduate             No        9100000
# 4        4                  3       Graduate             No        8200000
#
#     loan_amount   loan_term   credit_score   residential_assets_value  \
# 0      29900000          12          778.0                    2400000
# 1      12200000           8          417.0                    2700000
# 2      29700000          20          506.0                    7100000
# 3      29700000          20          506.0                    7100000
# 4      30700000           8          467.0                   18200000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4270 entries, 0 to 4269
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4270 non-null   int64
#  1    no_of_dependents          4270 non-null   int64
#  2    education                 4270 non-null   str
#  3    self_employed             4270 non-null   str
#  4    income_annum              4270 non-null   int64
#  5    loan_amount               4270 non-null   int64
#  6    loan_term                 4270 non-null   int64
#  7    credit_score              4266 non-null   float64
#  8    residential_assets_value  4270 non-null   int64
#  9    commercial_assets_value   4270 non-null   int64
#  10   luxury_assets_value       4270 non-null   int64
#  11   bank_asset_value          4270 non-null   int64
#  12   loan_status               4270 non-null   str
# dtypes: float64(1), int64(9), str(3)
# ...

# %%
data.shape
# Out:
# (4270, 13)

# %%
data.nunique()
# Out:
# loan_id                      4269
#  no_of_dependents               6
#  education                      2
#  self_employed                  2
#  income_annum                  98
#  loan_amount                  378
#  loan_term                     10
#  credit_score                 601
#  residential_assets_value     278
#  commercial_assets_value      188
#  luxury_assets_value          379
#  bank_asset_value             146
#  loan_status                    2
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4265    False
# 4266    False
# 4267    False
# 4268    False
# 4269    False
# Length: 4270, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data_new = data.drop_duplicates(keep='first').reset_index(drop=True)

# %%
data_new.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_new.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   credit_score   residential_assets_value  \
# 0      29900000          12          778.0                    2400000
# 1      12200000           8          417.0                    2700000
# 2      29700000          20          506.0                    7100000
# 3      30700000           8          467.0                   18200000
# 4      24200000          20          382.0                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...
