# %%
# !python3 -m pip install gensim
# Out:
# ...
#   Using cached numpy-2.4.6-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 7.6 MB/s  0:00:03m0:00:0100:01
# Using cached numpy-2.4.6-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [gensim]2m4/5 [gensim]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import gensim.downloader as api
model = api.load('word2vec-google-news-300')
# Out:
# [--------------------------------------------------] 1.4% 23.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [==------------------------------------------------] 4.6% 76.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [====----------------------------------------------] 8.2% 136.2/1662.8MB downloaded
# IOPub message rate exceeded.
# ...

# %%
vector = model['run']

# %%
vector
# Out:
# array([-7.32421875e-02,  8.39843750e-02, -7.44628906e-03,  3.97949219e-02,
#         5.20019531e-02, -2.08007812e-01,  1.19628906e-02, -2.25585938e-01,
#         2.00195312e-02,  2.63671875e-01,  1.36718750e-01, -1.07421875e-02,
#        -1.21582031e-01,  1.20117188e-01, -3.51562500e-02,  1.19140625e-01,
#         1.88476562e-01,  1.94335938e-01,  2.14843750e-02, -1.30859375e-01,
#        -6.44531250e-02,  2.04101562e-01,  2.04101562e-01,  1.54876709e-03,
#         2.08007812e-01,  6.34765625e-02, -6.25000000e-02,  6.68945312e-02,
#        -1.35742188e-01, -6.78710938e-02,  4.88281250e-02,  1.30859375e-01,
#        -9.71679688e-02, -1.15234375e-01, -5.15136719e-02, -1.37329102e-02,
#        -1.59179688e-01, -1.54296875e-01,  6.07910156e-02,  1.83593750e-01,
#         3.00781250e-01,  1.33056641e-02,  5.63964844e-02,  1.07421875e-01,
#        -4.34570312e-02,  1.72851562e-01, -9.37500000e-02,  7.61718750e-02,
# ...

# %%
vector.shape
# Out:
# (300,)

# %%
model = api.load('glove-wiki-gigaword-100')
# Out:
# [=========-----------------------------------------] 18.3% 23.4/128.1MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=======================---------------------------] 47.9% 61.3/128.1MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [===================================---------------] 71.0% 90.9/128.1MB downloaded
# IOPub message rate exceeded.
# ...

# %%
vector = model['run']

# %%
vector
# Out:
# array([-0.083289 ,  0.23917  ,  0.07881  , -0.72503  ,  0.52946  ,
#         0.3875   ,  0.022961 ,  0.49681  , -0.48814  , -0.096189 ,
#         0.44905  ,  0.43837  ,  0.53357  ,  0.095115 , -0.13968  ,
#        -0.11212  ,  0.29896  ,  0.26341  , -0.66897  ,  0.22975  ,
#         0.89879  ,  0.34643  ,  0.25615  ,  0.21586  ,  0.21425  ,
#        -0.24169  , -0.86973  ,  0.020957 ,  0.10059  ,  0.3516   ,
#        -0.31627  ,  0.5443   ,  0.23263  ,  0.1419   , -0.013273 ,
#         0.52183  , -0.59547  ,  0.2262   , -0.24309  ,  0.48833  ,
#         0.46244  ,  0.062477 , -0.70846  , -0.19034  , -0.0098881,
#        -0.29842  ,  0.71964  , -1.0293   ,  0.10814  , -0.58236  ,
#        -0.74859  ,  0.2608   ,  0.36313  ,  0.89341  ,  0.12908  ,
#        -2.7729   , -0.24366  ,  0.78553  ,  2.0139   ,  0.77937  ,
#        -0.68242  , -0.48596  ,  0.23694  ,  0.32044  ,  1.0055   ,
#         0.4407   ,  0.62289  , -0.12394  , -0.28919  ,  0.42294  ,
# ...

# %%
vector.shape
# Out:
# (100,)

# %%
vector = model['every']

# %%
vector
# Out:
# array([-0.27727  ,  0.92661  ,  0.17315  , -0.045406 , -0.083358 ,
#         1.0465   ,  0.21713  ,  0.87501  ,  0.036217 , -0.15929  ,
#         0.10976  ,  0.092062 ,  0.25409  , -0.22369  ,  0.14463  ,
#        -0.24954  ,  0.12295  ,  0.39308  , -0.47693  ,  0.10553  ,
#         0.22801  , -0.19551  , -0.24259  , -0.51512  ,  0.43307  ,
#        -0.30607  ,  0.1884   , -0.29352  ,  0.36087  , -0.27278  ,
#        -0.21983  ,  0.66602  ,  0.98997  ,  0.053121 , -0.15588  ,
#         0.2673   , -1.1178   ,  0.19931  ,  0.46937  , -0.29042  ,
#        -0.36779  , -0.15665  , -0.14155  ,  0.10562  , -0.1457   ,
#         0.21764  ,  0.14797  , -0.59431  , -0.53249  , -1.1898   ,
#         0.323    , -0.38777  ,  0.20736  ,  1.2764   , -0.23234  ,
#        -2.2816   , -0.28274  ,  0.0069935,  2.307    ,  0.19357  ,
#         0.023473 ,  0.88994  , -0.95999  , -0.0084821,  0.68624  ,
#         0.2331   ,  0.52896  , -0.2702   ,  0.16818  ,  0.013838 ,
# ...

# %%
# !python3 -m pip install spacy
# Out:
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# ...
#   Using cached cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...

# %%
# !python3 -m spacy download en_core_web_trf
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 148, in _get_module_details
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/Users/prreddy/Documents/EDUeki/AIML/AIML04/github/AIML04/ML/NLP/venv/lib/python3.11/site-packages/spacy/__init__.py", line 18, in <module>
#     from .cli.info import info  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/prreddy/Documents/EDUeki/AIML/AIML04/github/AIML04/ML/NLP/venv/lib/python3.11/site-packages/spacy/cli/__init__.py", line 4, in <module>
#     from . import download as download_module  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/prreddy/Documents/EDUeki/AIML/AIML04/github/AIML04/ML/NLP/venv/lib/python3.11/site-packages/spacy/cli/download.py", line 21, in <module>
#     from ._util import SDIST_SUFFIX, WHEEL_SUFFIX, Arg, Opt, app
# ...

# %%
# !python3 -m pip install click
# Out:
# ...
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !python3 -m spacy download en_core_web_trf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 27.2 MB/s  0:00:13:00:0100:01
# ...
#   Using cached spacy_curated_transformers-0.3.1-py2.py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# ...
#   Using cached curated_tokenizers-0.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.9 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
# Using cached spacy_curated_transformers-0.3.1-py2.py3-none-any.whl (237 kB)
# Using cached curated_tokenizers-0.0.9-cp311-cp311-macosx_11_0_arm64.whl (703 kB)
# Using cached curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 MB 18.2 MB/s  0:00:06 eta 0:00:01
# ...
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ...

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_trf")

# %%
doc = nlp("This is a sentence.")

# %%
doc
# Out:
# This is a sentence.

# %%
doc.vector
# Out:
# array([], dtype=float32)

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for i in doc:
    print (i.pos_)
# Out:
# PRON
# AUX
# DET
# NOUN
# PUNCT

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("This is a sentence.")

# %%
for i in doc:
    print (i)
# Out:
# This
# is
# a
# sentence
# .

# %%
for i in doc:
    print (i.vector)
# Out:
# [-0.30222663 -0.5066826   0.40728372  0.74863464  0.2632161  -0.06323725
#   0.19541897 -0.50713074 -0.647213   -0.5104113   0.49779475  1.398852
#   0.800985   -0.36767685 -1.015197   -0.6454387  -0.8550915   0.70902395
#  -0.72719383  0.91345054 -0.8968248   0.731345   -0.6765557  -0.0858016
#  -0.76394796 -0.27016097  0.5528437  -0.08582705 -0.3145975   1.2243465
#  -0.03030737 -0.8472374  -0.12998414 -0.3712472  -0.1776178   0.1235933
#  -1.1158838   0.24487399  0.38872495  2.0974367  -0.2351785  -0.8005934
#  -1.1312424   1.3534963  -0.09894016  0.50441355  0.00949386  2.0634909
#   0.7930522  -0.60283285 -0.29175055  0.09422258 -0.04815569  0.5854355
#   0.8479069  -0.61728334  0.01801094 -0.5350123  -0.34801203  0.06941123
#   0.32673633 -0.54763705 -0.1318251  -1.2727597   0.17005564 -0.64796937
#   1.4492002  -1.2342285  -0.63338715 -1.1739495  -0.97259605  0.4818985
#  -0.43342376  0.03856495 -0.19293231 -0.14533442 -0.03875555 -0.01663914
# ...

# %%
# !python3 -m pip install nltk
# Out:
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.1 MB/s  0:00:00 eta 0:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nltk]1/2 [nltk]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from nltk.tokenize import sent_tokenize

# %%
response = sent_tokenize ("This is my sentense for testing. This is another sentense")

# %%
response
# Out:
# ['This is my sentense for testing.', 'This is another sentense']

# %%
from nltk.tokenize import word_tokenize

# %%
response = word_tokenize ("This is my sentense for testing. This is another sentense")

# %%
response
# Out:
# ['This',
#  'is',
#  'my',
#  'sentense',
#  'for',
#  'testing',
#  '.',
#  'This',
#  'is',
#  'another',
#  'sentense']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 response.vector
#
# AttributeError: 'list' object has no attribute 'vector'

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nlp = spacy.load("en_core_web_lg")
#
# File ~/Documents/EDUeki/AIML/AIML04/github/AIML04/ML/NLP/venv/lib/python3.11/site-packages/spacy/__init__.py:74, in load(name, vocab, disable, enable, exclude, config)
#      50 def load(
#      51     name: Union[str, Path],
#      52     *,
#    (...)     57     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      58 ) -> Language:
#      59     """Load a spaCy model from an installed package or a local path.
#      60
#      61     name (str): Package name or model path.
#    (...)     72     RETURNS (Language): The loaded nlp object.
#      73     """
# ---> 74     return util.load_model(
#      75         name,
#      76         vocab=vocab,
#      77         disable=disable,
#      78         enable=enable,
# ...

# %%
# !python3 -m spacy download en_core_web_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 55.6 MB/s  0:00:07:00:0100:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp("I run every day. He runs on weekends. We were running yesterday")

# %%
doc
# Out:
# I run every day. He runs on weekends. We were running yesterday

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for token in doc:
    print (token)
# Out:
# I
# run
# every
# day
# .
# He
# runs
# on
# weekends
# .
# We
# were
# running
# yesterday

# %%
for token in doc:
    print (token, "|", token.lemma_)
# Out:
# I | I
# run | run
# every | every
# day | day
# . | .
# He | he
# runs | run
# on | on
# weekends | weekend
# . | .
# We | we
# were | be
# running | run
# yesterday | yesterday

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
stemmer.stem("runs")
# Out:
# 'run'

# %%
doc = nlp("Apple is looking at buying a U.K. startup for $1 billion in 2026.")

# %%
doc = nlp("Apple is looking at buying a U.K. startup for $1 billion in 2026.")

# %%
# 3. Iterate over the detected entities
for ent in doc.ents:
    print(ent, "|", ent.label_)
# Out:
# Apple | ORG
# U.K. | GPE
# $1 billion | MONEY
# 2026 | DATE
