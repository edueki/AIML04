# %% [markdown]
# # Salary Prediction V2

# %%
# !python3 -m pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("m_employee_data.csv")

# %%
data.head()
# Out:
#    Experience_Years  Projects_Completed Job_Title  Certificates_Completed  \
# 0                 7                  35       Mid                       3
# 1                20                  44      Lead                       3
# 2                15                  40    Senior                       5
# 3                11                  22    Senior                       4
# 4                 8                  27    Junior                       5
#
#      Salary
# 0  50691.07
# 1  86962.17
# 2  70537.40
# 3  59026.32
# 4  59124.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Experience_Years        100 non-null    int64
#  1   Projects_Completed      100 non-null    int64
#  2   Job_Title               100 non-null    object
#  3   Certificates_Completed  100 non-null    int64
#  4   Salary                  100 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 4.0+ KB

# %%
data.shape
# Out:
# (100, 5)

# %%
data.nunique()
# Out:
# Experience_Years           20
# Projects_Completed         40
# Job_Title                   5
# Certificates_Completed      6
# Salary                    100
# dtype: int64

# %%
# !python3 -m pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(6,6))
plt.scatter(data['Experience_Years'], data['Salary'], color="blue", label="Experience")
plt.scatter(data['Projects_Completed'], data['Salary'], color="red", label="projects")
plt.scatter(data['Job_Title'], data['Salary'], color="green", label="job")
plt.scatter(data['Certificates_Completed'], data['Salary'], color="orange", label="certificates")
plt.xlabel("Features")
plt.ylabel("Salary")
plt.title("Experience vs. salary")
plt.legend()
plt.show()

# %%
data.head()
# Out:
#    Experience_Years  Projects_Completed Job_Title  Certificates_Completed  \
# 0                 7                  35       Mid                       3
# 1                20                  44      Lead                       3
# 2                15                  40    Senior                       5
# 3                11                  22    Senior                       4
# 4                 8                  27    Junior                       5
#
#      Salary
# 0  50691.07
# 1  86962.17
# 2  70537.40
# 3  59026.32
# 4  59124.94

# %%
data_encoded = pd.get_dummies(data, columns=['Job_Title'])

# %%
data_encoded.head()
# Out:
#    Experience_Years  Projects_Completed  Certificates_Completed    Salary  \
# 0                 7                  35                       3  50691.07
# 1                20                  44                       3  86962.17
# 2                15                  40                       5  70537.40
# 3                11                  22                       4  59026.32
# 4                 8                  27                       5  59124.94
#
#    Job_Title_Junior  Job_Title_Lead  Job_Title_Manager  Job_Title_Mid  \
# 0             False           False              False           True
# 1             False            True              False          False
# 2             False           False              False          False
# 3             False           False              False          False
# 4              True           False              False          False
#
#    Job_Title_Senior
# 0             False
# 1             False
# 2              True
# ...

# %%
# !python3 -m pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
y = data_encoded['Salary']

# %%
X = data_encoded.drop(columns=['Salary'])

# %%
X.head()
# Out:
#    Experience_Years  Projects_Completed  Certificates_Completed  \
# 0                 7                  35                       3
# 1                20                  44                       3
# 2                15                  40                       5
# 3                11                  22                       4
# 4                 8                  27                       5
#
#    Job_Title_Junior  Job_Title_Lead  Job_Title_Manager  Job_Title_Mid  \
# 0             False           False              False           True
# 1             False            True              False          False
# 2             False           False              False          False
# 3             False           False              False          False
# 4              True           False              False          False
#
#    Job_Title_Senior
# 0             False
# 1             False
# 2              True
# 3              True
# 4             False

# %%
y
# Out:
# 0     50691.07
# 1     86962.17
# 2     70537.40
# 3     59026.32
# 4     59124.94
#         ...
# 95    57014.19
# 96    38675.60
# 97    50197.07
# 98    60972.51
# 99    49593.07
# Name: Salary, Length: 100, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=45)

# %%
X_train.shape
# Out:
# (60, 8)

# %%
X_test.shape
# Out:
# (40, 8)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train )
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 1862.9631053 ,   213.66971897,   940.6132172 ,   267.54999613,
#        -2544.18007447,  7880.12220501, -3004.14336301, -2599.34876366])

# %%
model.intercept_
# Out:
# np.float64(31094.57607670986)

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([51431.45426619, 78032.96539428, 59884.25937189, 51422.27708049,
#        52549.21054416, 51959.63566824, 45576.13184189, 37865.75863   ,
#        69689.52873714, 56690.58803637, 41546.62573239, 83794.27049411,
#        84262.20098894, 73120.13239692, 40220.47411357, 56737.97941329,
#        58811.06998942, 57942.69347018, 53019.65984953, 65239.91710021,
#        56059.9513855 , 48856.45528545, 53687.56241995, 55650.82038808,
#        59699.88836618, 67133.09875638, 62991.41559328, 63858.04969092,
#        69221.31406607, 60213.16214544, 35358.52829591, 44840.31682884,
#        75004.68396866, 64523.93595513, 63256.33305141, 68081.31862041,
#        43412.84690958, 47633.78357034, 72342.75777796, 49703.83318536])

# %%
y_test
# Out:
# 0     50691.07
# 1     86962.17
# 62    55255.02
# 76    60227.39
# 37    56110.52
# 99    49593.07
# 78    48109.76
# 38    33895.30
# 2     70537.40
# 84    56108.90
# 60    45464.31
# 26    85937.16
# 69    75442.14
# 33    70320.69
# 51    35886.50
# 4     59124.94
# 92    48838.77
# 7     58827.49
# 10    60027.27
# 74    69227.08
# 45    41310.92
# 9     43833.35
# 20    57719.10
# 18    62534.56
# 73    64993.88
# 19    32980.83
# 25    57078.06
# 21    68673.17
# 70    71835.49
# 23    60102.37
# 97    50197.07
# 90    47220.60
# 29    36174.65
# 67    67786.64
# 5     59828.78
# 82    70084.98
# 28    47362.06
# 43    46410.65
# 63    71399.09
# 66    50495.49
# Name: Salary, dtype: float64

# %%
X_test.head(3)
# Out:
#     Experience_Years  Projects_Completed  Certificates_Completed  \
# 0                  7                  35                       3
# 1                 20                  44                       3
# 62                16                   3                       1
#
#     Job_Title_Junior  Job_Title_Lead  Job_Title_Manager  Job_Title_Mid  \
# 0              False           False              False           True
# 1              False            True              False          False
# 62             False           False              False          False
#
#     Job_Title_Senior
# 0              False
# 1              False
# 62              True

# %%
y_test.head(3)
# Out:
# 0     50691.07
# 1     86962.17
# 62    55255.02
# Name: Salary, dtype: float64

# %%
predictions
# Out:
# array([51431.45426619, 78032.96539428, 59884.25937189, 51422.27708049,
#        52549.21054416, 51959.63566824, 45576.13184189, 37865.75863   ,
#        69689.52873714, 56690.58803637, 41546.62573239, 83794.27049411,
#        84262.20098894, 73120.13239692, 40220.47411357, 56737.97941329,
#        58811.06998942, 57942.69347018, 53019.65984953, 65239.91710021,
#        56059.9513855 , 48856.45528545, 53687.56241995, 55650.82038808,
#        59699.88836618, 67133.09875638, 62991.41559328, 63858.04969092,
#        69221.31406607, 60213.16214544, 35358.52829591, 44840.31682884,
#        75004.68396866, 64523.93595513, 63256.33305141, 68081.31862041,
#        43412.84690958, 47633.78357034, 72342.75777796, 49703.83318536])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, predictions)
# Out:
# 0.4283495143775746
