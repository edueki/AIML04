# %% [markdown]
# # Cosine Similarity - word

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Load a small pretrained model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Words (or short texts)
words = ["cat", "cats", "kitten", "dog", "dogs", "milk", "silk"]

# Convert to embeddings
embeddings = model.encode(words, convert_to_tensor=False)

# Compute cosine similarity
cos_sim = cosine_similarity(embeddings)

# Display results as a DataFrame
df = pd.DataFrame(cos_sim, index=words, columns=words)
print(df.round(3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# WARNING:tensorflow:From D:\EDUeki Learning\AMPT\Learning\pr\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#           cat   cats  kitten    dog   dogs   milk   silk
# cat     1.000  0.870   0.788  0.661  0.575  0.342  0.176
# cats    0.870  1.000   0.743  0.567  0.715  0.363  0.183
# kitten  0.788  0.743   1.000  0.521  0.453  0.311  0.254
# dog     0.661  0.567   0.521  1.000  0.824  0.371  0.274
# dogs    0.575  0.715   0.453  0.824  1.000  0.391  0.262
# milk    0.342  0.363   0.311  0.371  0.391  1.000  0.365
# silk    0.176  0.183   0.254  0.274  0.262  0.365  1.000

# %% [markdown]
# # Cosine Similarity - Sentense

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load pretrained sentence embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Query and candidates
query = "Can you give me best investing options?"
sent1 = "A kitten likes to drink milk."
sent2 = "Stock prices increased yesterday."

# Encode
embeddings = model.encode([query, sent1, sent2], convert_to_tensor=False)

# Compute cosine similarity of query vs each candidate
sim_query_sent1 = cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]
sim_query_sent2 = cosine_similarity([embeddings[0]], [embeddings[2]])[0][0]

print("Query:", query)
print("Sentence 1:", sent1, "→ Similarity:", round(sim_query_sent1, 3))
print("Sentence 2:", sent2, "→ Similarity:", round(sim_query_sent2, 3))

if sim_query_sent1 > sim_query_sent2:
    print("\nSentence 1 is more similar to the query.")
else:
    print("\nSentence 2 is more similar to the query.")
# Out:
# Query: Can you give me best investing options?
# Sentence 1: A kitten likes to drink milk. → Similarity: 0.011
# Sentence 2: Stock prices increased yesterday. → Similarity: 0.238
#
# Sentence 2 is more similar to the query.

# %% [markdown]
# # ChromaDB

# %%
import chromadb

# %%
chroma_client = chromadb.Client()

# %%
collection = chroma_client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "Oranges are very sweet & healthy",
        "Orange is bright colour"
    ],
    ids=["id1", "id2"]
)

# %%
collection.peek()
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': array([[ 1.85966324e-02, -1.66588649e-02,  5.93799748e-04,
#           1.28125146e-01, -5.61542902e-03,  2.09736899e-02,
#           6.02619350e-02, -3.03189736e-02,  2.58360077e-02,
#          -3.10340188e-02,  2.54585464e-02,  3.52508761e-02,
#          -4.68438193e-02, -5.59613667e-02,  5.09437509e-02,
#           8.19939226e-02,  7.51795024e-02, -5.23920730e-02,
#          -1.01085663e-01, -9.20305494e-03, -1.29376380e-02,
#          -7.23995864e-02,  4.86832596e-02,  6.45977333e-02,
#          -5.21541946e-02, -2.70127524e-02,  5.33109419e-02,
#          -2.50075981e-02, -3.43400463e-02, -3.59926149e-02,
#          -5.32587171e-02, -1.83577687e-02,  9.49271247e-02,
#           5.94063709e-03, -8.80596712e-02, -9.77594331e-02,
#           1.02583215e-01, -7.25067705e-02, -3.09198797e-02,
#          -2.53512594e-03, -4.77523776e-03,  4.32436876e-02,
#           2.31515965e-03,  4.84592989e-02, -2.46634688e-02,
#          -9.61348531e-04, -5.51934317e-02, -5.24972193e-02,
#           1.90147255e-02,  5.01197502e-02, -8.82169753e-02,
#          -8.07054807e-03, -4.29279497e-03, -4.64661643e-02,
#          -4.54606256e-03,  3.34592126e-02, -8.38175490e-02,
#          -5.13981394e-02, -7.62225166e-02,  6.14361577e-02,
#           1.21367276e-01,  3.61167389e-04,  2.08654031e-02,
#          -4.32802066e-02, -5.76248430e-02, -1.17617454e-02,
#          -1.49273537e-02,  1.09085953e-02,  9.38158948e-03,
#          -7.35350698e-02, -4.18239869e-02,  3.92439775e-02,
#           2.55449805e-02,  1.13172196e-01, -1.21720387e-02,
#           6.37785867e-02,  5.49722314e-02, -1.67040224e-03,
#          -4.68525738e-02,  7.42033310e-03, -2.81946398e-02,
#           2.18613669e-02, -8.23334306e-02,  1.75934713e-02,
#           1.46867000e-02, -1.83040369e-02, -5.21637090e-02,
#          -3.04259565e-02,  5.27140219e-03,  1.48087487e-01,
#           5.75887971e-04,  7.13592023e-03,  8.53402466e-02,
#           3.68915088e-02, -5.00130560e-03, -5.96106872e-02,
#           2.09161825e-02, -1.09451182e-01, -3.02716019e-03,
#           3.34011801e-02,  7.07589509e-03,  4.10351418e-02,
#           1.08976755e-02, -2.10798271e-02, -2.82004233e-02,
#           3.79911885e-02, -2.37745587e-02, -4.02511843e-02,
#          -1.63125582e-02,  7.00833872e-02,  8.14817399e-02,
#          -9.04732849e-03,  4.96253707e-02,  5.13756881e-03,
#          -4.64067459e-02, -6.11724295e-02,  6.93057373e-04,
#           1.43994540e-02, -1.69423707e-02,  3.11281942e-02,
#          -2.55451109e-02, -5.70141384e-03, -6.41517062e-03,
#           2.67548803e-02, -2.44030319e-02, -3.62752490e-02,
#           9.67913400e-03, -2.08886301e-33,  1.57759134e-02,
#           3.56752761e-02,  5.14303222e-02,  1.46948155e-02,
#           1.69455521e-02,  1.13786431e-02, -3.82540002e-02,
#          -4.64504100e-02,  6.03696406e-02, -3.40041853e-02,
#          -1.21998675e-01, -2.60245316e-02, -4.40846495e-02,
#          -3.89885455e-02,  2.40516532e-02, -6.23590685e-03,
#          -4.76452475e-03,  1.85810570e-02, -9.11796615e-02,
#           1.03222124e-01, -9.01461393e-02, -3.00129075e-02,
#          -4.01931866e-05, -2.18382441e-02, -6.67127967e-02,
#           2.31304746e-02, -6.30807653e-02, -1.29664233e-02,
#          -1.35575957e-03, -9.48472705e-04,  2.54129209e-02,
#           7.07980059e-03,  3.59937083e-03,  4.51483317e-02,
#          -5.40174209e-02, -1.59114189e-02, -4.52648848e-03,
#           7.31572043e-03,  6.40152171e-02,  7.25076348e-02,
#           3.76918986e-02,  2.15802435e-02,  5.23226755e-03,
#           1.23712741e-01, -6.65663835e-03, -5.86544238e-02,
#           1.66182928e-02,  5.93899861e-02,  3.51215675e-02,
#          -8.27718005e-02, -1.21091969e-01, -5.34417368e-02,
#           2.56607425e-03,  4.61974815e-02,  2.01014057e-02,
#          -4.67186198e-02, -1.17724324e-02,  4.53689918e-02,
#          -3.32109854e-02,  3.53562646e-02, -8.34814310e-02,
#           7.22058024e-03,  2.30317004e-03, -6.01218231e-02,
#          -1.29650429e-01, -2.55825184e-02, -1.28802627e-01,
#           2.57967971e-02, -7.75253177e-02,  9.55683086e-03,
#           8.11785311e-02,  1.82226226e-02,  4.09875438e-02,
#          -5.07913902e-02, -3.38374339e-02, -2.65798159e-02,
#           5.66982627e-02,  9.91266873e-03,  6.25597760e-02,
#           6.19819015e-02, -2.32556579e-03,  4.43057381e-02,
#          -2.07856158e-03,  7.65036494e-02, -7.19585805e-04,
#           8.93300101e-02, -5.51414266e-02,  4.88924384e-02,
#           7.70236254e-02,  5.88602163e-02, -1.18296742e-01,
#           2.79269759e-02, -8.07824638e-03, -4.67055775e-02,
#          -1.82797406e-02,  4.51293587e-34,  4.37862054e-02,
#           9.36868694e-03, -1.14581063e-02,  3.53127718e-02,
#           8.58381093e-02, -2.99242698e-02, -7.76290670e-02,
#           2.50110012e-02, -3.61230038e-02, -2.69524697e-02,
#           2.35920167e-03, -7.05659809e-03, -9.00194980e-03,
#           1.64034199e-02,  4.53121029e-02,  5.19151799e-02,
#           6.58945590e-02,  1.47651151e-01, -4.56380770e-02,
#          -8.15022923e-03, -1.05549447e-01,  7.04004318e-02,
#           1.51665658e-02,  1.59691684e-02, -2.92101055e-02,
#           3.94929200e-02, -5.86888306e-02, -1.92985646e-02,
#          -1.02963857e-02,  6.63292259e-02,  1.01683587e-01,
#          -4.49605584e-02, -4.47198264e-02, -7.51795545e-02,
#           6.04359321e-02, -6.43351721e-03,  4.32391325e-03,
#          -9.45282951e-02, -7.67049640e-02,  1.11478254e-01,
#           7.11359968e-03, -2.31598988e-02, -1.24243479e-02,
#           1.24302907e-02,  2.67070141e-02,  3.24927792e-02,
#          -1.54298050e-02, -2.15111896e-02, -1.77295785e-02,
#           9.23688989e-03,  7.96048194e-02, -9.85508505e-03,
#          -6.80712461e-02,  7.50624835e-02,  2.04852950e-02,
#          -2.78858077e-02, -1.02832615e-02,  4.18277308e-02,
#          -4.55435738e-02, -5.39755933e-02, -9.29027051e-02,
#          -5.71893081e-02,  5.96569013e-03, -1.50189279e-02,
#          -1.49570052e-02,  2.19002808e-03,  5.75429276e-02,
#           6.47174343e-02, -4.80007455e-02, -4.79197279e-02,
#          -4.01772745e-02, -2.25948431e-02, -3.85575928e-02,
#           1.51959797e-02,  8.18059295e-02, -4.39861305e-02,
#          -1.20452726e-02, -1.35133499e-02,  5.26345475e-03,
#           4.55686934e-02, -6.66978508e-02, -5.08358143e-02,
#          -5.89581765e-03, -2.05901023e-02, -4.47505899e-02,
#           8.20998698e-02, -1.39862951e-02, -3.46521735e-02,
#          -1.51293511e-02,  5.24349101e-02, -5.38113900e-02,
#          -1.26049025e-02,  4.60861297e-03,  4.38797884e-02,
#          -1.51923103e-02, -1.46876467e-08,  1.28937855e-01,
#          -6.44943342e-02, -5.70344329e-02,  5.83055131e-02,
#          -9.01199579e-02, -3.20986472e-02, -6.61698729e-02,
#           5.48292734e-02, -1.65646318e-02,  1.12208659e-02,
#           2.45193653e-02,  1.01729363e-01, -1.29932184e-02,
#           2.80647520e-02, -1.63066462e-02, -7.15753287e-02,
#           4.29041460e-02,  8.07983875e-02,  1.83991827e-02,
#           8.75875875e-02, -9.54893678e-02,  6.76797256e-02,
#           1.58580788e-03,  2.40897574e-02,  1.03921909e-02,
#          -1.00647146e-02, -2.18948163e-02, -2.23617293e-02,
#           7.94485491e-03,  5.97656146e-02,  1.00301556e-01,
#           2.44631413e-02,  3.99484597e-02,  5.24085984e-02,
#           2.49060914e-02, -5.52552454e-02,  4.81919199e-02,
#          -1.72680579e-02, -7.38822892e-02, -2.91871540e-02,
#          -3.99097800e-02, -2.99677923e-02, -1.04542427e-01,
#           4.11056876e-02, -7.26855407e-03, -1.26070315e-02,
#           3.72296534e-02,  8.21165219e-02, -4.37771194e-02,
#           1.93161834e-02, -4.90295738e-02,  5.58949299e-02,
#          -3.55937518e-02,  9.43107083e-02, -5.06929569e-02,
#          -4.45594825e-02,  8.90960917e-02, -6.21861964e-02,
#          -1.09597361e-02, -3.12720612e-03,  6.91298172e-02,
#           1.66288670e-02,  1.04169939e-02, -4.36449349e-02],
#         [ 1.09686051e-02,  1.40463011e-02, -1.02040293e-02,
#           4.26493101e-02,  8.43710005e-02, -4.23621684e-02,
#           1.48135036e-01, -4.38345112e-02,  6.86279982e-02,
#          -5.71135245e-02, -1.45813413e-02,  1.76034626e-02,
#          -2.75435839e-02,  2.40020081e-02, -7.13653350e-03,
#           1.10552885e-01,  8.67321268e-02, -2.27941852e-02,
#          -1.19571090e-01, -5.52307218e-02, -3.59504074e-02,
#          -3.48489173e-02,  8.48378707e-03, -1.48815205e-02,
#          -8.41468722e-02, -2.98563894e-02,  3.58291641e-02,
#           4.01085652e-02, -1.50179267e-02, -7.18519837e-02,
#          -5.85833983e-03,  2.00985745e-02,  7.73094893e-02,
#           1.74139626e-03, -6.83733895e-02, -1.07798316e-01,
#           6.66081235e-02, -3.20685990e-02, -4.10693027e-02,
#           2.84788944e-02,  4.80381399e-03, -7.61240767e-03,
#           2.41789240e-02,  3.69234830e-02, -1.21518513e-02,
#           3.41928713e-02, -3.73387262e-02, -1.36190280e-02,
#          -1.21791223e-02, -1.54734524e-02, -3.45132798e-02,
#          -5.65228127e-02, -3.45873162e-02, -7.71149918e-02,
#          -8.41496065e-02,  6.66824654e-02, -4.44379784e-02,
#          -7.39657059e-02, -1.88799063e-03,  4.64929789e-02,
#           7.52367303e-02,  3.03156162e-03,  2.20765173e-02,
#           1.58288311e-02, -2.57432219e-02,  8.40063300e-03,
#           2.88884225e-03, -7.62201622e-02,  2.03802995e-03,
#          -1.08750314e-01,  4.40874621e-02,  6.91925809e-02,
#           8.18675384e-02,  1.11634783e-01,  2.67210808e-02,
#           3.33103128e-02,  6.95146099e-02,  4.52628061e-02,
#           9.85271949e-03, -1.28609478e-03, -8.19789595e-04,
#           2.00910196e-02, -1.43083617e-01,  3.06344647e-02,
#           8.05703029e-02,  2.97658108e-02, -9.50100943e-02,
#          -4.56710160e-03, -4.84890938e-02,  1.18486866e-01,
#          -6.52180389e-02,  8.69903564e-02,  1.93093736e-02,
#           1.95645895e-02, -1.29912328e-02, -3.40828374e-02,
#           4.70602699e-02, -5.28331585e-02, -1.97700784e-02,
#           7.60433078e-02,  2.18760576e-02,  8.17880705e-02,
#          -2.31406745e-03,  2.68418342e-02, -2.57241782e-02,
#          -8.29654410e-02,  7.49471691e-03, -7.05989962e-03,
#          -2.99052931e-02,  4.55078408e-02,  7.89186656e-02,
#          -5.00966646e-02,  1.71556789e-02, -3.70300859e-02,
#          -7.85876065e-03, -2.09580082e-02, -3.20870802e-02,
#           3.50704305e-02, -3.13918851e-02,  6.49134144e-02,
#           4.78785597e-02,  4.07466618e-03, -8.58152360e-02,
#           6.26540408e-02, -1.38802314e-02, -1.98758859e-02,
#           6.01425245e-02, -2.31666684e-33,  6.44154400e-02,
#           1.99751854e-02,  5.01728468e-02,  1.28960973e-02,
#           8.55440199e-02, -2.32337750e-02, -1.83598977e-02,
#          -7.43934140e-02, -3.10018118e-02, -1.48604559e-02,
#          -3.17084268e-02,  1.51303075e-02, -5.81698045e-02,
#           2.64976267e-02,  4.52878177e-02, -3.63724418e-02,
#           4.18462120e-02,  4.26753275e-02, -1.30504146e-01,
#           4.65325527e-02, -4.88603227e-02,  4.66765352e-02,
#          -1.79269332e-02, -4.80918698e-02, -4.38410155e-02,
#           4.00044098e-02, -4.99228425e-02, -1.79785956e-02,
#          -2.32385052e-03,  1.43273436e-02,  6.53355867e-02,
#          -3.61044030e-03,  2.25181449e-02,  8.66096765e-02,
#          -8.66587535e-02, -7.51428232e-02,  4.64942306e-03,
#          -1.71088912e-02,  8.56663734e-02,  1.00962058e-01,
#          -4.25601192e-02,  3.30540761e-02, -3.74704693e-03,
#           1.24864161e-01, -3.39718238e-02,  4.13231552e-03,
#           3.45779508e-02,  3.52749936e-02,  3.13480124e-02,
#           1.58470273e-02, -9.38873664e-02, -9.16368812e-02,
#           1.05104884e-02,  3.65827535e-03, -9.97964479e-03,
#          -5.06263506e-03,  3.85628780e-03,  8.04450586e-02,
#           1.60855744e-02, -3.48651111e-02, -3.05967312e-02,
#           5.45332283e-02, -7.10527692e-03,  1.71307810e-02,
#          -6.61293939e-02,  1.23677333e-03, -6.86679035e-02,
#           1.23495224e-03, -6.61208900e-03, -1.38688972e-02,
#           3.13055739e-02, -7.39704468e-04,  7.47174621e-02,
#          -8.01594183e-02, -5.83853014e-02, -3.46727595e-02,
#           8.88036788e-02, -3.60353217e-02,  3.36390287e-02,
#          -2.27264641e-03, -9.97077748e-02, -6.51949178e-03,
#           2.40728315e-02,  1.64737401e-04, -4.92671803e-02,
#           4.26159799e-02, -1.06255885e-03,  7.85213113e-02,
#          -2.21448261e-02,  7.45372698e-02, -3.13759260e-02,
#           2.18820646e-02, -2.63010114e-02, -7.36986771e-02,
#          -6.45350153e-03,  9.57399190e-34,  6.66981712e-02,
#          -4.54836944e-03, -6.22189492e-02,  9.31354892e-03,
#           3.68464291e-02, -4.39211316e-02, -7.46084079e-02,
#           5.40707372e-02, -7.45875090e-02,  2.86519248e-03,
#           5.41584976e-02,  8.87034088e-03, -3.60233560e-02,
#           5.19705974e-02,  4.90310825e-02, -5.09856362e-03,
#           7.91423246e-02,  1.43968850e-01, -9.53817274e-03,
#           4.23119552e-02, -1.29871294e-01,  6.27581263e-03,
#           4.35316283e-03,  1.49086129e-03, -1.05082872e-03,
#           4.56483737e-02, -2.17102412e-02, -9.47059318e-02,
#          -1.02066085e-01,  2.44725272e-02, -3.26299369e-02,
#          -6.80630375e-03,  2.48250365e-03,  3.89687195e-02,
#           1.27108078e-02,  1.39717683e-02,  9.93071198e-02,
#          -1.93334639e-01, -6.49840757e-02,  8.56776983e-02,
#          -3.62388678e-02, -4.62966599e-02,  1.81153417e-02,
#          -3.82627314e-03, -2.82931048e-02,  4.48435359e-03,
#          -2.52147093e-02,  1.63796954e-02,  2.64126472e-02,
#          -9.76403151e-03,  1.08337201e-01,  1.72294036e-03,
#           1.80668682e-02,  5.30137122e-02,  1.51026854e-02,
#          -2.43622828e-02, -3.09381913e-02,  2.99238786e-02,
#          -3.54197174e-02,  6.88228980e-02,  7.77533231e-03,
#          -1.41705051e-02, -5.11277877e-02, -6.68202934e-04,
#          -6.65709435e-04,  1.54128671e-02,  7.17392936e-02,
#           4.59679328e-02, -1.40461996e-02, -1.09242862e-02,
#          -5.30788861e-03, -2.29711048e-02, -5.53780943e-02,
#          -1.37239397e-02,  1.28878266e-01, -6.96170405e-02,
#           2.73892982e-03,  3.13971452e-02, -2.84423623e-02,
#           9.28382576e-02, -8.14535990e-02, -3.19965146e-02,
#           2.97042560e-02,  2.71175615e-02, -5.30419685e-02,
#           4.75701466e-02,  4.91956435e-03,  3.14609632e-02,
#           3.39940074e-03, -4.01773565e-02, -3.56100053e-02,
#           5.33811226e-02, -3.11868135e-02,  3.04963789e-03,
#          -3.38019617e-02, -1.48152139e-08,  5.93928397e-02,
#          -1.06195293e-01, -3.63374278e-02,  1.75207842e-03,
#          -4.42870297e-02, -3.80634628e-02,  1.77228439e-03,
#          -3.17587052e-04, -5.26682585e-02, -2.98985951e-02,
#           4.45353147e-03,  4.26214896e-02,  5.84196718e-03,
#           5.36573865e-02,  4.57284264e-02, -7.02348650e-02,
#          -8.19922537e-02,  3.42641696e-02,  7.53947394e-03,
#           5.92970736e-02, -4.54575941e-02,  5.79989552e-02,
#           4.63885330e-02, -5.40849380e-03,  2.40764208e-02,
#           3.59614603e-02, -8.22075531e-02,  2.57116202e-02,
#           2.47613247e-02,  6.63823411e-02,  4.45904061e-02,
#           2.95503698e-02, -1.34653142e-02, -4.43897536e-03,
#          -4.37965281e-02, -3.73738930e-02,  1.92137230e-02,
#           1.81873441e-02, -6.86868727e-02, -9.52760968e-03,
#          -4.61511910e-02, -3.79564613e-02, -7.30063096e-02,
#           4.78125140e-02,  3.49834561e-02,  1.58067923e-02,
#           1.22525636e-02, -1.00480570e-02, -7.50631243e-02,
#          -6.32820874e-02, -3.93194407e-02,  3.83058451e-02,
#           3.70058184e-03,  5.81354499e-02, -7.94657618e-02,
#          -1.17644362e-01,  2.55182688e-03, -1.58898868e-02,
#          -3.52714546e-02, -4.81660856e-04,  5.67184687e-02,
#           3.64863686e-02,  3.98737146e-03, -7.39559997e-03]]),
#  'documents': ['Oranges are very sweet & healthy', 'Orange is bright colour'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
results = collection.query(
    query_texts=["Life is colourfull!"], # Chroma will embed this for you
    n_results=2 # how many results to return
)

results
# Out:
# {'ids': [['id2', 'id1']],
#  'embeddings': None,
#  'documents': [['Orange is bright colour',
#    'Oranges are very sweet & healthy']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.2615089416503906, 1.6319520473480225]]}

# %% [markdown]
# # ChromaDB - PDF document with PersistentClient

# %%
# pip install pypdf sentence-transformers chromadb

import chromadb
from PyPDF2 import PdfReader
from sentence_transformers import SentenceTransformer

# 1. Read PDF text
reader = PdfReader("AIML.pdf")
pages = [page.extract_text() for page in reader.pages]
full_text = " ".join(pages)

# 2. Simple chunking
chunks = [full_text[i:i+500] for i in range(0, len(full_text), 500)]

# 3. Embed chunks
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(chunks).tolist()

# 4. Store in Chroma
# Inline Memory
#client = chromadb.Client()
client = chromadb.PersistentClient(path="./vector_db")
#Persistent Client
coll = client.create_collection(name="stocks")

coll.add(
    documents=chunks,
    embeddings=embeddings,
    ids=[f"chunk_{i}" for i in range(len(chunks))],
    metadatas=[{"source": "AIML.pdf"} for _ in chunks]
)

print("Stored", len(chunks), "chunks from AIML.pdf")
# Out:
# Stored 13 chunks from AIML.pdf

# %%
query = "Can you give me oops concepts"
res = coll.query(query_texts=[query], n_results=3)

top_doc = res["documents"][0][0]
top_dist = res["distances"][0][0]

print("Best Match:\n")
print(top_doc)   # full text of the document
print(f"\nDistance: {top_dist:.4f}")
# Out:
# Best Match:
#
# es Concept 7: File & Data Processor
# If
# If-else
# If-elif-else
# Nested-if
# for
# while
# Nested loops
# Break
# ContinueConcept 8: Control Flow
#  Built-in Functions
# User Defined Functions
# Function Arguments
# Function Return Values Concept 9: Functions
# Learn how to handle Python exceptions and raise exceptions.
# Understand Try, except, else, finally, and creating custom exceptions.Concept 10: Exception Handling
# Module Introduction
# Package Management
# Create Python Packages
# Understand how you can write modular
#
# Distance: 1.1546
